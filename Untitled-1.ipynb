# %%
import os
import cv2
import numpy as np
import pandas as pd
from skimage import io, img_as_float
from skimage.filters import sobel
from scipy.stats import skew, kurtosis, entropy
import matplotlib.pyplot as plt

# %%
def load_gray(img_path,size=(512,512)):
    img=io.imread(img_path, as_gray=True)
    img=img_as_float(img)
    return cv2.resize(img,size, interpolation=cv2.INTER_AREA)

# %%
def extract_features(img,file_path,scanner_id="unknown"):
    h,w=img.shape
    aspect_ratio=w/h
    file_size_kb=os.path.getsize(file_path)/1024  # in KB
    pixels=img.flatten()
    mean_intensity=np.mean(pixels)
    std_intensity=np.std(pixels)
    skewness=skew(pixels)
    kurt=kurtosis(pixels)
    ent=entropy(np.histogram(pixels, bins=256, range=(0, 1))[0]+1e-6)
    edges=sobel(img)
    edge_density=np.mean(edges>0.1)
    return {
        "file_name": os.path.basename(file_path),
        "class_label": scanner_id,
        #"width": w,
        #"height": h,
        #"aspect_ratio": aspect_ratio,
        #"file_size_kb": file_size_kb,
        "mean_intensity": mean_intensity,
        "std_intensity": std_intensity,
        "skewness": skewness,
        "kurtosis": kurt,
        "entropy": ent,
        "edge_density": edge_density
    }

# %%
columns = [
    "file_name","class_label","width", "height", "aspect_ratio", "file_size_kb",
    "mean_intensity", "std_intensity", "skewness", "kurtosis",
    "entropy", "edge_density"
]

# %%
metadata = pd.DataFrame(columns=columns)

# %%
def process_image_and_add(df,img_path,scanner_id="unknown"):
    img=load_gray(img_path)
    features=extract_features(img,img_path,scanner_id)
    return pd.concat([df, pd.DataFrame([features])], ignore_index=True)

def process_image_and_append(df, img_path, scanner_id="unknown"):
    img = load_gray(img_path)
    features = extract_features(img, img_path, scanner_id)
    df.loc[len(df)] = features
    return df

# %%
dataset_dir = r"D:\jupyter\Datasets\Official"

# %%
metadata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 225 entries, 0 to 224
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   file_name       225 non-null    object
#  1   class_label     225 non-null    object
#  2   width           225 non-null    int64
#  3   height          225 non-null    int64
#  4   aspect_ratio    225 non-null    float64
#  5   file_size_kb    225 non-null    float64
#  6   mean_intensity  225 non-null    float64
#  7   std_intensity   225 non-null    float64
#  8   skewness        225 non-null    float64
#  9   kurtosis        225 non-null    float64
#  10  entropy         225 non-null    float64
#  11  edge_density    225 non-null    float64
# dtypes: float64(8), int64(2), object(2)
# memory usage: 22.9+ KB

# %%
metadata["class_label"].value_counts()
# Out:
# class_label
# HP             53
# EpsonV370-2    40
# Canon120-1     24
# EpsonV550      21
# Canon120-2     19
# EpsonV39-1     19
# Canon9000-2    17
# Canon220       15
# EpsonV370-1    13
# Canon9000-1     3
# EpsonV39-2      1
# Name: count, dtype: int64

# %%
metadata.head()
# Out:
#    file_name class_label  width  height  aspect_ratio  file_size_kb  \
# 0  s1_13.tif  Canon120-1    512     512           1.0   6366.801758
# 1  s1_19.tif  Canon120-1    512     512           1.0   6366.801758
# 2  s1_22.tif  Canon120-1    512     512           1.0   6366.801758
# 3  s1_23.tif  Canon120-1    512     512           1.0   6366.801758
# 4  s1_26.tif  Canon120-1    512     512           1.0   6366.801758
#
#    mean_intensity  std_intensity  skewness    kurtosis   entropy  edge_density
# 0        0.980218       0.077358 -4.790764   25.914771  0.781967      0.109833
# 1        0.971157       0.096124 -4.117721   17.967127  1.149003      0.153709
# 2        0.993663       0.046020 -9.545255  105.365174  0.302918      0.035507
# 3        0.986276       0.061183 -5.732387   36.103704  0.747618      0.068008
# 4        0.984811       0.074763 -6.015534   40.108241  0.576405      0.074955

# %%
metadata.describe()
# Out:
#        width  height  aspect_ratio  file_size_kb  mean_intensity  \
# count  225.0   225.0         225.0    225.000000      225.000000
# mean   512.0   512.0           1.0  17808.650699        0.964888
# std      0.0     0.0           0.0   9374.952600        0.022817
# min    512.0   512.0           1.0   6275.959961        0.898533
# 25%    512.0   512.0           1.0   6366.801758        0.947987
# 50%    512.0   512.0           1.0  25352.668945        0.975061
# 75%    512.0   512.0           1.0  25495.071289        0.982437
# max    512.0   512.0           1.0  25495.073242        0.993663
#
#        std_intensity    skewness    kurtosis     entropy  edge_density
# count     225.000000  225.000000  225.000000  225.000000    225.000000
# mean        0.081251   -5.029062   29.972324    1.550351      0.096996
# std         0.020768    1.375110   17.076014    0.755877      0.044108
# min         0.044467   -9.545255    0.736546    0.302918      0.031990
# 25%         0.063414   -5.846635   17.458369    0.871004      0.065777
# 50%         0.080251   -5.031291   27.702308    1.398749      0.086563
# 75%         0.093943   -4.117721   38.236931    2.308847      0.119751
# max         0.160209   -1.595270  105.365174    3.206845      0.251602

# %%
for root, dirs, files in os.walk(dataset_dir):
    for file in files:
        if file.lower().endswith(('.tif', '.jpg', '.png')):
            img_path = os.path.join(root, file)
            relative_path = os.path.relpath(img_path, dataset_dir)
            scanner_id = relative_path.split(os.sep)[0]
            
            print(f"Processing: {file} | Scanner ID: {scanner_id}")
            metadata = process_image_and_append(metadata, img_path, scanner_id)
# Out:
# Processing: s1_13.tif | Scanner ID: Canon120-1
# Processing: s1_19.tif | Scanner ID: Canon120-1
# Processing: s1_22.tif | Scanner ID: Canon120-1
# Processing: s1_23.tif | Scanner ID: Canon120-1
# Processing: s1_26.tif | Scanner ID: Canon120-1
# Processing: s1_3.tif | Scanner ID: Canon120-1
# Processing: s1_44.tif | Scanner ID: Canon120-1
# Processing: s1_49.tif | Scanner ID: Canon120-1
# Processing: s1_8.tif | Scanner ID: Canon120-1
# Processing: s1_16.tif | Scanner ID: Canon120-1
# Processing: s1_44.tif | Scanner ID: Canon120-1
# Processing: s1_45.tif | Scanner ID: Canon120-1
# Processing: s1_46.tif | Scanner ID: Canon120-1
# Processing: s1_47.tif | Scanner ID: Canon120-1
# Processing: s1_48.tif | Scanner ID: Canon120-1
# Processing: s1_49.tif | Scanner ID: Canon120-1
# Processing: s1_50.tif | Scanner ID: Canon120-1
# Processing: s1_52.tif | Scanner ID: Canon120-1
# Processing: s1_53.tif | Scanner ID: Canon120-1
# Processing: s1_54.tif | Scanner ID: Canon120-1
# Processing: s1_55.tif | Scanner ID: Canon120-1
# Processing: s1_56.tif | Scanner ID: Canon120-1
# Processing: s1_57.tif | Scanner ID: Canon120-1
# Processing: s1_58.tif | Scanner ID: Canon120-1
# Processing: s2_10.tif | Scanner ID: Canon120-2
# Processing: s2_100.tif | Scanner ID: Canon120-2
# Processing: s2_25.tif | Scanner ID: Canon120-2
# Processing: s2_26.tif | Scanner ID: Canon120-2
# Processing: s2_28.tif | Scanner ID: Canon120-2
# Processing: s2_36.tif | Scanner ID: Canon120-2
# Processing: s2_38.tif | Scanner ID: Canon120-2
# Processing: s2_39.tif | Scanner ID: Canon120-2
# Processing: s2_41.tif | Scanner ID: Canon120-2
# Processing: s2_42.tif | Scanner ID: Canon120-2
# Processing: s2_45.tif | Scanner ID: Canon120-2
# Processing: s7_34.tif | Scanner ID: EpsonV370-2
# Processing: s7_38.tif | Scanner ID: EpsonV370-2
# Processing: s7_39.tif | Scanner ID: EpsonV370-2
# Processing: s7_41.tif | Scanner ID: EpsonV370-2
# Processing: s7_5.tif | Scanner ID: EpsonV370-2
# Processing: s7_52.tif | Scanner ID: EpsonV370-2
# Processing: s7_54.tif | Scanner ID: EpsonV370-2
# Processing: s7_58.tif | Scanner ID: EpsonV370-2
# Processing: s7_61.tif | Scanner ID: EpsonV370-2
# Processing: s7_65.tif | Scanner ID: EpsonV370-2
# Processing: s7_75.tif | Scanner ID: EpsonV370-2
# Processing: s7_76.tif | Scanner ID: EpsonV370-2
# Processing: s7_81.tif | Scanner ID: EpsonV370-2
# Processing: s7_84.tif | Scanner ID: EpsonV370-2
# Processing: s7_85.tif | Scanner ID: EpsonV370-2
# Processing: s7_88.tif | Scanner ID: EpsonV370-2
# Processing: s7_94.tif | Scanner ID: EpsonV370-2
# Processing: s7_95.tif | Scanner ID: EpsonV370-2
# Processing: s7_98.tif | Scanner ID: EpsonV370-2
# Processing: s7_35.tif | Scanner ID: EpsonV370-2
# Processing: s7_51.tif | Scanner ID: EpsonV370-2
# Processing: s7_71.tif | Scanner ID: EpsonV370-2
# Processing: s7_72.tif | Scanner ID: EpsonV370-2
# Processing: s7_73.tif | Scanner ID: EpsonV370-2
# Processing: s7_74.tif | Scanner ID: EpsonV370-2
# Processing: s7_75.tif | Scanner ID: EpsonV370-2
# Processing: s7_76.tif | Scanner ID: EpsonV370-2
# Processing: s7_77.tif | Scanner ID: EpsonV370-2
# Processing: s7_78.tif | Scanner ID: EpsonV370-2
# Processing: s7_79.tif | Scanner ID: EpsonV370-2
# Processing: s7_81.tif | Scanner ID: EpsonV370-2
# Processing: s7_82.tif | Scanner ID: EpsonV370-2
# Processing: s7_83.tif | Scanner ID: EpsonV370-2
# Processing: s7_84.tif | Scanner ID: EpsonV370-2
# Processing: s7_85.tif | Scanner ID: EpsonV370-2
# Processing: s8_2.tif | Scanner ID: EpsonV39-1
# Processing: s8_26.tif | Scanner ID: EpsonV39-1
# Processing: s8_70.tif | Scanner ID: EpsonV39-1
# Processing: s8_71.tif | Scanner ID: EpsonV39-1
# Processing: s8_72.tif | Scanner ID: EpsonV39-1
# Processing: s8_73.tif | Scanner ID: EpsonV39-1
# Processing: s8_74.tif | Scanner ID: EpsonV39-1
# Processing: s8_75.tif | Scanner ID: EpsonV39-1
# Processing: s8_76.tif | Scanner ID: EpsonV39-1
# Processing: s8_77.tif | Scanner ID: EpsonV39-1
# Processing: s8_78.tif | Scanner ID: EpsonV39-1
# Processing: s8_79.tif | Scanner ID: EpsonV39-1
# Processing: s8_80.tif | Scanner ID: EpsonV39-1
# Processing: s8_81.tif | Scanner ID: EpsonV39-1
# Processing: s8_82.tif | Scanner ID: EpsonV39-1
# Processing: s8_83.tif | Scanner ID: EpsonV39-1
# Processing: s8_84.tif | Scanner ID: EpsonV39-1
# Processing: s8_85.tif | Scanner ID: EpsonV39-1
# Processing: s8_86.tif | Scanner ID: EpsonV39-1
# Processing: s9_96.tif | Scanner ID: EpsonV39-2
# Processing: s10_14.tif | Scanner ID: EpsonV550
# Processing: s10_28.tif | Scanner ID: EpsonV550
# Processing: s10_36.tif | Scanner ID: EpsonV550
# Processing: s10_38.tif | Scanner ID: EpsonV550
